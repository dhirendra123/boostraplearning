# %% [markdown]
# <a href="https://colab.research.google.com/github/dhirendra123/boostraplearning/blob/master/python_for_intermidiate_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list is a stucture for data collection and its also a data type 
# list mutable , ordered , alllow duplicate elements ,iterable
# creating list using [] square bracket and seprated by ,  commas
my_list=["banana","cherry","apple"]
print(my_list)
print(type(my_list)) # checking the data type using type() function 
# creating empty list using list() function 
myempty_list=list()
print(myempty_list)
print(type(myempty_list))

# list of multiple data type
mymulti_list=["hello",1,True,50.5,]
print(mymulti_list)

# acccessing list element using indexNo  
element_1=my_list[0]
print(element_1) 
# acccessing list element using  nagtiveindexNo
element_lastsecond=my_list[-2]
print(element_lastsecond)  
# iterating list using foor loop 
for item in mymulti_list:
  print(item,end=" ")
#checking element exixts in list or not using if 
if 50.5 in mymulti_list:
  print("\n")
  print("the item exist in list" )
else:
  print("item dosen't exists")

#checking the length of list using len() method 
length_list=len(mymulti_list)
print(length_list)

#apppending item in the list ,append() add item in the last of the list 
mymulti_list.append("Dehradun")
#append takes only one arguments if given more than 1 it will throw error 
# ....'''mymulti_list.append("delhi",1090)'''
print(mymulti_list)

#adding item in specific indexNo using insert() method 
# insert() method takes two arguments insert(indexno,value) =insert(1,"dehradun")
# insert() method shift the list top the right 
mymulti_list.insert(1,"delhi")
# the following line throw error bcz we only provide 1 value 
# mymulti_list.insert(False)
print(mymulti_list)
# extending the list  using extend()  method 
# extend()  method  add the item in the last after itarating it 
mymulti_list.extend("united_kingdom")
print("extend method also include the - in the list ")
print(mymulti_list)
# after addding the space in string it will also count the space 
print("extend method also include the space in the list ")
mymulti_list.extend("united kingdom")
print(mymulti_list)
# deleting item form the last of the list using pop() method
# pop() method return thelast item of list 
print("checking length of mymulti_list before pop()")
print(len(mymulti_list))
print("pop return the last item of list here")
lastitem_mymultilist=mymulti_list.pop()
print(lastitem_mymultilist)
print("checking length of mymulti_list after pop()")
print(len(mymulti_list))
# removing particular item from the list using remove method 
# remove() method doesn't return the item its return none 
#it will sift the list element to the left 
remove_item=mymulti_list.remove(50.5)
print("the removed doesn't retrn the item  ")
print(remove_item)
print(mymulti_list)
print(len(mymulti_list))
# clear the list using clear() method 
# clear() method make it empty list
mymulti_list2=mymulti_list
print("this is mymulti_list2")
print(mymulti_list2)
mymulti_list.clear()
print("here is the empty list after apply clear method ")
print(mymulti_list)
# reverse  the list using reverse() method 
# reverse()  method does'nt retrun anything  
print("printing the reverse list ")
print(my_list)
my_list.reverse()
print(my_list)
mymulti_list2.reverse()
print(mymulti_list2)
# sorting the list using sort() method 
unsort_list=[55,10,80,5,34,25,100,500,50,80,20,-5,-1] 
print(unsort_list)
# sort () method dosent return anthing its change the original list type none 
sorted_list=unsort_list.sort()
print("sort method retrun none bcz its dosent return anything ")
print(sorted_list)
print("this is sorted list ")
print(unsort_list)
# creating a list of same element in multiple time tricks
print("this is a list of 10 of 6 time") 
list1=[10]*6
print(list1)
# slicing a list using : colon/slicing  operator
print("this is the slicices list of index no 2 to till indexNo 5 excluding indexNo 6 ")
print(unsort_list[2:6])
print("this is the slicices list of index no 0 to till last of the list ")
print(unsort_list[0:])
print("this is the slicices list of index no 0 to till inedexNo 6 of the list ")
print(unsort_list[:7])
# list copy method for original copy method ()
list_org=["delhi","dehradun","australia","new york","pakistan"]
# this is the copy assigenment of list but its one in loaction  
listcopy1=list_org
print(listcopy1)
# this is different copy of list_org in different location  
listrealcopy=list_org.copy()
print(listrealcopy)
# appending the item in listcopy1 a and it will also add in list_org
listcopy1.append("rassia")
print("this is copy list appending rassia ")
print(listcopy1)
print("this is list_org appending rassia automatically from listcopy1 bcz both are same")
print(list_org) 
#appending item in listrealcopy it will not add in list_org
listrealcopy.append("10000")
print("here listreal copy appending 10000")
print(listrealcopy)
print("here list_org doesn't append 10000 bcz both are differnt ")
print(list_org)
# nested list means list inside list
nested_list=["rahul","noida",1,67,["delhi",56,20.56,"himanchal"],[10,40,80.5],"jagdish"]
print("this is th example of nested list ")
print(nested_list)
# Out:
# ['banana', 'cherry', 'apple']
# <class 'list'>
# []
# <class 'list'>
# ['hello', 1, True, 50.5]
# banana
# cherry
# hello 1 True 50.5
#
# the item exist in list
# 4
# ['hello', 1, True, 50.5, 'Dehradun']
# ['hello', 'delhi', 1, True, 50.5, 'Dehradun']
# extend method also include the - in the list
# ['hello', 'delhi', 1, True, 50.5, 'Dehradun', 'u', 'n', 'i', 't', 'e', 'd', '_', 'k', 'i', 'n', 'g', 'd', 'o', 'm']
# extend method also include the space in the list
# ['hello', 'delhi', 1, True, 50.5, 'Dehradun', 'u', 'n', 'i', 't', 'e', 'd', '_', 'k', 'i', 'n', 'g', 'd', 'o', 'm', 'u', 'n', 'i', 't', 'e', 'd', ' ', 'k', 'i', 'n', 'g', 'd', 'o', 'm']
# checking length of mymulti_list before pop()
# 34
# pop return the last item of list here
# m
# checking length of mymulti_list after pop()
# 33
# the removed doesn't retrn the item
# None
# ...

# %% [markdown]
# #
